# %% [markdown]
# ## Task 3
# ## Registration ID : SIRSS1237
# ## Nagineni Prasad

# %%
# Q1.write a funcion to return n-th term of Fibonacci Series

num = int(input("Enter the nth number :"))

def fib_series(number):
    if (number ==0 or number ==1):
        return 1
    else:
        first = 0
        second = 1
        for i in range(2,num):
            next_element = first + second
            first = second
            second= next_element
            
        return next_element
    
fib_series(num)
# Out:
# Enter the nth number : 5
# 3

# %%
# Q2. write a function to find out the GCD of two numbers using EUCLID's Algorithm.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

def GCD(a,b):
    while(a!=b):
        if (a>b):
            a = a-b
        else:
            b=b-a
            
    return a

GCD(a,b)
# Out:
# Enter first number:  6
# Enter second number:  8
# 2

# %%
# Q3. Write a function to find out the LCM of two numbers 

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

def GCD(a,b):
    if(a==0):
        return b
    return GCD(b%a,a)

def lcm(a,b):
    return (a / GCD(a,b))*b;

lcm(a,b)
# Out:
# Enter first number:  12
# Enter second number:  24
# 24.0
